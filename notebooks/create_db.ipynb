# %%
# Importing all the required libraries
import sqlite3 as sql 
import os 

import pandas as pd 
import numpy as np 

import matplotlib.pyplot as plt 
import seaborn as sns 

import warnings 
warnings.filterwarnings('ignore')

pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
pd.set_option('display.max_colwidth',None)

# %%
CSV_FILE_PATH = os.path.join('Data','raw' , 'amazon_sales_2025_INR.csv')
PROCESSED_DIR = os.path.join('Data', 'processed')
DB_FILE_PATH = os.path.join('Data','processed','amazon_sales_2025.db')

TABLE_NAME = 'sales_data'

try : 

    print(f"Reading csv from: {CSV_FILE_PATH}")

    df = pd.read_csv(CSV_FILE_PATH)

    os.makedirs(PROCESSED_DIR, exist_ok=True)
    print(f"Ensuring directory {PROCESSED_DIR} exists.")
    
    conn = sql.connect(DB_FILE_PATH)
    df.to_sql(TABLE_NAME , conn , if_exists='replace' , index = False)

    print(f"\nSuccessfully loaded {len(df)} rows into table {TABLE_NAME}")
    print(f"Database created at: {DB_FILE_PATH}")


    conn.commit()
    conn.close()


except FileNotFoundError : 
    print(f"ERROR: CSV file not found at {CSV_FILE_PATH}.Check your path and file name.")

except Exception as e : 
    print(f'An error occurred: {e}')
# Out:
# Reading csv from: Data/raw/amazon_sales_2025_INR.csv
# Ensuring directory Data/processed exists.
#
# Successfully loaded 15000 rows into table sales_data
# Database created at: Data/processed/amazon_sales_2025.db
